# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/content/autodata.csv')
df.head()
# Out:
#    Unnamed: 0  symboling  normalized-losses         make aspiration  \
# 0           0          3                122  alfa-romero        std
# 1           1          3                122  alfa-romero        std
# 2           2          1                122  alfa-romero        std
# 3           3          2                164         audi        std
# 4           4          2                164         audi        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    compression-ratio  horsepower  peak-rpm  city-mpg highway-mpg  price  \
# ...

# %%
df.tail()
# Out:
#      Unnamed: 0  symboling  normalized-losses   make aspiration num-of-doors  \
# 196         196         -1                 95  volvo        std         four
# 197         197         -1                 95  volvo      turbo         four
# 198         198         -1                 95  volvo        std         four
# 199         199         -1                 95  volvo      turbo         four
# 200         200         -1                 95  volvo      turbo         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  \
# 196      sedan          rwd           front       109.1  ...
# 197      sedan          rwd           front       109.1  ...
# 198      sedan          rwd           front       109.1  ...
# 199      sedan          rwd           front       109.1  ...
# 200      sedan          rwd           front       109.1  ...
#
#      compression-ratio  horsepower  peak-rpm  city-mpg highway-mpg  price  \
# ...

# %%
df.shape
# Out:
# (201, 30)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 30 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         201 non-null    int64
#  1   symboling          201 non-null    int64
#  2   normalized-losses  201 non-null    int64
#  3   make               201 non-null    object
#  4   aspiration         201 non-null    object
#  5   num-of-doors       201 non-null    object
#  6   body-style         201 non-null    object
#  7   drive-wheels       201 non-null    object
#  8   engine-location    201 non-null    object
#  9   wheel-base         201 non-null    float64
#  10  length             201 non-null    float64
#  11  width              201 non-null    float64
#  12  height             201 non-null    float64
#  13  curb-weight        201 non-null    int64
#  14  engine-type        201 non-null    object
#  15  num-of-cylinders   201 non-null    object
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0             int64
# symboling              int64
# normalized-losses      int64
# make                  object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                  int64
# city-L/100km         float64
# horsepower-binned     object
# diesel                 int64
# gas                    int64
# dtype: object

# %%
df.isnull()
# Out:
#      Unnamed: 0  symboling  normalized-losses   make  aspiration  \
# 0         False      False              False  False       False
# 1         False      False              False  False       False
# 2         False      False              False  False       False
# 3         False      False              False  False       False
# 4         False      False              False  False       False
# ..          ...        ...                ...    ...         ...
# 196       False      False              False  False       False
# 197       False      False              False  False       False
# 198       False      False              False  False       False
# 199       False      False              False  False       False
# 200       False      False              False  False       False
#
#      num-of-doors  body-style  drive-wheels  engine-location  wheel-base  ...  \
# 0           False       False         False            False       False  ...
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0            0
# symboling             0
# normalized-losses     0
# make                  0
# aspiration            0
# num-of-doors          0
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                 17
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 0
# city-L/100km          0
# horsepower-binned     2
# diesel                0
# gas                   0
# dtype: int64

# %%
df.replace(np.nan,df['bore'].mean(),inplace=True)

# %%
df.replace(np.nan,df['stroke'].mean(),inplace=True)

# %%
df.replace(np.nan,df['horsepower'].mean(),inplace=True)

# %%
df.replace(np.nan,df['peak-rpm'].mean(),inplace=True)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# symboling            0
# normalized-losses    0
# make                 0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# city-L/100km         0
# horsepower-binned    0
# diesel               0
# gas                  0
# dtype: int64

# %%
df.iloc[5]
# Out:
# Unnamed: 0                   5
# symboling                    2
# normalized-losses          122
# make                      audi
# aspiration                 std
# num-of-doors               two
# body-style               sedan
# drive-wheels               fwd
# engine-location          front
# wheel-base                99.8
# length                0.851994
# width                 0.920833
# height                    53.1
# curb-weight               2507
# engine-type                ohc
# num-of-cylinders          five
# engine-size                136
# fuel-system               mpfi
# bore                  3.336842
# stroke                     3.4
# compression-ratio          8.5
# horsepower               110.0
# peak-rpm                5500.0
# city-mpg                    19
# highway-mpg                 25
# price                    15250
# city-L/100km         12.368421
# horsepower-binned          Low
# diesel                       0
# gas                          1
# ...

# %%
df.iloc[:5,:3]
# Out:
#    Unnamed: 0  symboling  normalized-losses
# 0           0          3                122
# 1           1          3                122
# 2           2          1                122
# 3           3          2                164
# 4           4          2                164

# %%
df['stroke']=df['stroke'].astype('int')
print(df['stroke'])
# Out:
# 0      2
# 1      2
# 2      3
# 3      3
# 4      3
#       ..
# 196    3
# 197    3
# 198    2
# 199    3
# 200    3
# Name: stroke, Length: 201, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
data=df['body-style']
label_encoder=LabelEncoder()
encoded_data=label_encoder.fit_transform(data)
print(df.head())
# Out:
#    Unnamed: 0  symboling  normalized-losses         make aspiration  \
# 0           0          3                122  alfa-romero        std
# 1           1          3                122  alfa-romero        std
# 2           2          1                122  alfa-romero        std
# 3           3          2                164         audi        std
# 4           4          2                164         audi        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    compression-ratio  horsepower  peak-rpm  city-mpg highway-mpg  price  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder

df['HB']=df['body-style'].str[0]
label_encoder=LabelEncoder()
df['HB encoded']=label_encoder.fit_transform(df['HB'])
print(df[['body-style','HB','HB encoded']].sample(n=10))
# Out:
#     body-style HB  HB encoded
# 73   hatchback  h           1
# 14       sedan  s           2
# 104      sedan  s           2
# 187      sedan  s           2
# 13       sedan  s           2
# 76   hatchback  h           1
# 189      wagon  w           3
# 16       sedan  s           2
# 106      wagon  w           3
# 85       sedan  s           2

# %%
df
# Out:
#      Unnamed: 0  symboling  normalized-losses         make aspiration  \
# 0             0          3                122  alfa-romero        std
# 1             1          3                122  alfa-romero        std
# 2             2          1                122  alfa-romero        std
# 3             3          2                164         audi        std
# 4             4          2                164         audi        std
# ..          ...        ...                ...          ...        ...
# 196         196         -1                 95        volvo        std
# 197         197         -1                 95        volvo      turbo
# 198         198         -1                 95        volvo        std
# 199         199         -1                 95        volvo      turbo
# 200         200         -1                 95        volvo      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# ...
