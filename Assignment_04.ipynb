# %%
import pandas as pd
import numpy as np
import sklearn

# %%
data = pd.read_csv('/content/boston.csv')
data
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO   BLACK  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO   BLACK  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
data.tail()
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 501  0.06263  0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527  0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076  0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959  0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741  0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO   BLACK  LSTAT  MEDV
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  BLACK    506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
data.dtypes
# Out:
# CRIM       float64
# ZN         float64
# INDUS      float64
# CHAS         int64
# NOX        float64
# RM         float64
# AGE        float64
# DIS        float64
# RAD          int64
# TAX        float64
# PTRATIO    float64
# BLACK      float64
# LSTAT      float64
# MEDV       float64
# dtype: object

# %%
data.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# BLACK      0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X= data.iloc[:,0:13]
y= data.iloc[:,-1]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.20, random_state=4)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (404, 13)
# (102, 13)
# (404,)
# (102,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

# %%
model = make_pipeline(StandardScaler(), LinearRegression())
model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('linearregression', LinearRegression())])

# %%
model.score(X_test,y_test)
# Out:
# 0.726345145970251

# %%
y_pre=model.predict(X_test)

# %%
num_samples = len(y_test)

# %%
for i in range(num_samples):
  pre_price=y_pre[i].item()
  actual_price=y_test.iloc[i].item()
  print(f"Sample {i+1}: Predicted Price: ${pre_price:.2f}, Actual Price: ${actual_price}")
# Out:
# Sample 1: Predicted Price: $12.07, Actual Price: $16.5
# Sample 2: Predicted Price: $26.99, Actual Price: $24.8
# Sample 3: Predicted Price: $17.59, Actual Price: $17.4
# Sample 4: Predicted Price: $18.16, Actual Price: $19.3
# Sample 5: Predicted Price: $36.92, Actual Price: $37.6
# Sample 6: Predicted Price: $25.43, Actual Price: $24.2
# Sample 7: Predicted Price: $31.09, Actual Price: $35.4
# Sample 8: Predicted Price: $19.73, Actual Price: $19.9
# Sample 9: Predicted Price: $19.66, Actual Price: $27.5
# Sample 10: Predicted Price: $22.96, Actual Price: $17.0
# Sample 11: Predicted Price: $28.39, Actual Price: $31.2
# Sample 12: Predicted Price: $28.49, Actual Price: $24.4
# Sample 13: Predicted Price: $19.00, Actual Price: $16.1
# Sample 14: Predicted Price: $32.41, Actual Price: $27.0
# Sample 15: Predicted Price: $21.52, Actual Price: $21.0
# Sample 16: Predicted Price: $15.26, Actual Price: $14.9
# Sample 17: Predicted Price: $21.23, Actual Price: $18.9
# Sample 18: Predicted Price: $11.62, Actual Price: $6.3
# Sample 19: Predicted Price: $11.37, Actual Price: $16.3
# Sample 20: Predicted Price: $13.64, Actual Price: $13.9
# Sample 21: Predicted Price: $5.62, Actual Price: $8.8
# Sample 22: Predicted Price: $17.35, Actual Price: $19.4
# Sample 23: Predicted Price: $20.81, Actual Price: $18.8
# Sample 24: Predicted Price: $22.51, Actual Price: $19.8
# Sample 25: Predicted Price: $16.39, Actual Price: $17.5
# Sample 26: Predicted Price: $20.32, Actual Price: $19.3
# Sample 27: Predicted Price: $17.89, Actual Price: $20.0
# Sample 28: Predicted Price: $14.23, Actual Price: $14.3
# Sample 29: Predicted Price: $21.12, Actual Price: $16.1
# Sample 30: Predicted Price: $17.51, Actual Price: $19.5
# Sample 31: Predicted Price: $14.54, Actual Price: $11.0
# Sample 32: Predicted Price: $23.63, Actual Price: $21.9
# Sample 33: Predicted Price: $34.32, Actual Price: $31.0
# Sample 34: Predicted Price: $22.23, Actual Price: $22.0
# Sample 35: Predicted Price: $16.82, Actual Price: $15.1
# Sample 36: Predicted Price: $20.16, Actual Price: $13.3
# Sample 37: Predicted Price: $30.68, Actual Price: $28.7
# Sample 38: Predicted Price: $35.62, Actual Price: $46.7
# Sample 39: Predicted Price: $23.50, Actual Price: $22.2
# Sample 40: Predicted Price: $24.66, Actual Price: $22.8
# Sample 41: Predicted Price: $36.91, Actual Price: $42.3
# Sample 42: Predicted Price: $32.33, Actual Price: $41.3
# Sample 43: Predicted Price: $19.12, Actual Price: $16.7
# Sample 44: Predicted Price: $32.20, Actual Price: $31.1
# Sample 45: Predicted Price: $33.43, Actual Price: $26.7
# Sample 46: Predicted Price: $25.53, Actual Price: $19.4
# Sample 47: Predicted Price: $40.63, Actual Price: $50.0
# Sample 48: Predicted Price: $18.22, Actual Price: $16.6
# Sample 49: Predicted Price: $19.35, Actual Price: $19.5
# Sample 50: Predicted Price: $23.80, Actual Price: $24.4
# Sample 51: Predicted Price: $33.42, Actual Price: $28.5
# Sample 52: Predicted Price: $26.15, Actual Price: $22.3
# Sample 53: Predicted Price: $18.10, Actual Price: $12.1
# Sample 54: Predicted Price: $28.20, Actual Price: $28.6
# Sample 55: Predicted Price: $13.37, Actual Price: $15.6
# Sample 56: Predicted Price: $23.34, Actual Price: $19.2
# Sample 57: Predicted Price: $24.45, Actual Price: $27.5
# Sample 58: Predicted Price: $33.55, Actual Price: $32.0
# Sample 59: Predicted Price: $16.71, Actual Price: $20.2
# Sample 60: Predicted Price: $36.56, Actual Price: $32.4
# Sample 61: Predicted Price: $15.70, Actual Price: $18.4
# Sample 62: Predicted Price: $18.55, Actual Price: $19.9
# Sample 63: Predicted Price: $32.15, Actual Price: $29.8
# Sample 64: Predicted Price: $15.50, Actual Price: $20.1
# Sample 65: Predicted Price: $39.02, Actual Price: $43.5
# Sample 66: Predicted Price: $27.38, Actual Price: $24.5
# Sample 67: Predicted Price: $31.96, Actual Price: $50.0
# Sample 68: Predicted Price: $10.09, Actual Price: $7.2
# Sample 69: Predicted Price: $19.13, Actual Price: $19.1
# Sample 70: Predicted Price: $21.73, Actual Price: $21.2
# Sample 71: Predicted Price: $23.15, Actual Price: $22.6
# Sample 72: Predicted Price: $22.83, Actual Price: $22.9
# Sample 73: Predicted Price: $22.51, Actual Price: $25.0
# Sample 74: Predicted Price: $28.21, Actual Price: $23.3
# Sample 75: Predicted Price: $17.13, Actual Price: $17.3
# Sample 76: Predicted Price: $23.08, Actual Price: $33.0
# Sample 77: Predicted Price: $16.66, Actual Price: $17.8
# Sample 78: Predicted Price: $25.18, Actual Price: $23.8
# Sample 79: Predicted Price: $13.69, Actual Price: $10.9
# Sample 80: Predicted Price: $19.82, Actual Price: $18.6
# Sample 81: Predicted Price: $22.31, Actual Price: $19.3
# Sample 82: Predicted Price: $20.25, Actual Price: $16.7
# Sample 83: Predicted Price: $28.36, Actual Price: $28.0
# Sample 84: Predicted Price: $19.13, Actual Price: $18.2
# Sample 85: Predicted Price: $30.49, Actual Price: $29.1
# Sample 86: Predicted Price: $22.26, Actual Price: $11.9
# Sample 87: Predicted Price: $29.98, Actual Price: $32.7
# Sample 88: Predicted Price: $19.28, Actual Price: $18.3
# Sample 89: Predicted Price: $23.74, Actual Price: $22.4
# Sample 90: Predicted Price: $38.32, Actual Price: $45.4
# Sample 91: Predicted Price: $31.25, Actual Price: $31.5
# Sample 92: Predicted Price: $41.92, Actual Price: $48.5
# Sample 93: Predicted Price: $18.61, Actual Price: $19.8
# Sample 94: Predicted Price: $37.48, Actual Price: $41.7
# Sample 95: Predicted Price: $19.66, Actual Price: $22.2
# Sample 96: Predicted Price: $23.45, Actual Price: $20.3
# Sample 97: Predicted Price: $26.55, Actual Price: $20.7
# Sample 98: Predicted Price: $22.38, Actual Price: $50.0
# Sample 99: Predicted Price: $9.59, Actual Price: $11.8
# Sample 100: Predicted Price: $20.39, Actual Price: $19.5
# Sample 101: Predicted Price: $9.23, Actual Price: $8.7
# Sample 102: Predicted Price: $27.36, Actual Price: $23.3
